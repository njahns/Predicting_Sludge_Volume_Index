# %% [markdown]
# # 3. Pre-processing Training & Data Development

# %% [markdown]
# Random Forests are generally not sensitive to feature scales and are generally capable of handling high-dimensional data, Therfore, scaling and dimension reduction was not performed at this time. Also, no data was missing so no values were imputed.

# %%
# Libraries imported for this notebook.

import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score

# %%
# Read EDA_Data.xlsx into a dataframe, formatted dates, and indexed dates.

df = pd.read_excel('/Users/NJahns/Desktop/Bootcamp/Capstone_Two/Edited_Data/EDA_Data.xlsx', parse_dates=True, index_col=[0])

# %%
# Looked at shape

df.shape
# Out:
# (2281, 20)

# %%
# Printed columns in data

for col in df.columns:
    print(col)
# Out:
# Sludge Volume Index
# SE NH3
# MLSS
# RAS TSS
# Alum Feed 1
# Alum Feed 2
# WAS Flow
# Primary Sludge A Flow
# Primary Sludge B Flow
# Ana F:M
# RAS Flow
# Avg ND Effluent Hourly Ammonia
# Avg ND WAS Flow
# Avg ND Aeration DO Cell 5 AVG
# Avg ND Aeration DO Cell 7 AVG
# Avg ND Aer. Avg Cell 7 Nitrate
# Avg ND Average Basin Airflow
# day
# month
# year

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Domain-specific

# %%
# Changed 'WAS Flow' to Sludge flow to avoid confusion with 'Avg ND WAS Flow'

df.rename(columns={'WAS Flow': 'Activated Sludge Flow'}, inplace=True)

# %%
# Added a column that is 'Total Alum Feed'

df['Total Alum Feed'] = df['Alum Feed 1'] + df['Alum Feed 2']

# %%
# Added a column that is 'Total Sludge Flow'

df['Total Primary Sludge Flow'] = df['Primary Sludge A Flow'] + df['Primary Sludge B Flow']

# %%
# Added a column that is 'Average ND Aeration DO in Cells'

df['Average ND Aeration DO in Cells'] = df[['Avg ND Aeration DO Cell 5 AVG', 'Avg ND Aeration DO Cell 7 AVG']].mean(axis=1)

# %%
# Added a column that is 'MVLSS' - Mixed Liquor Volatile Suspended Solids. The volotile fraction is roughly 75%.

df['MVLSS'] = df['MLSS'] * 0.75

# %%
# Added a column that is 'MCRT' - Mean Cell Residence Time

df['MCRT'] = df['MVLSS'] / (df['Activated Sludge Flow'] + df['RAS Flow'])

# %%
# Added a column that is 'Sludge Age'

df['Sludge Age'] = df['MCRT'] / (1 + df['Ana F:M'])

# %% [markdown]
# ### Temporal

# %% [markdown]
# Temporal features such as day of the week, month, and year were created in previous steps.

# %% [markdown]
# #### Differencing

# %% [markdown]
# Differencing was performed to compute the differences between consecutive data points. This technique is ofter perfomed for time series models and can transform a non-stationary time series into a stationary one and remove trends and seasonality. Overall, differencing can be beneficial because it stabilizes the mean and variance of the data, making it easier to identify underlying patterns and relationships.

# %%
# Performed differencing on data.

# Identified columns to exclude from differencing
exclude_columns = ['day', 'month', 'year']

# Performed first-order differencing on selected columns
first_differences = df.drop(columns=exclude_columns).diff().add_prefix('1st_')

# Performed second-order differencing on selected columns
second_differences = df.drop(columns=exclude_columns).diff().diff().add_prefix('2nd_')

# Concatenated the results with the original DataFrame
df = pd.concat([df, first_differences, second_differences], axis=1).dropna()

# %%
# Looked at just SVI to check differencing calculations.

selected_columns = ['Sludge Volume Index', '1st_Sludge Volume Index', '2nd_Sludge Volume Index']
new_df = df.loc[:, selected_columns]
new_df.head(10)
# Out:
#             Sludge Volume Index  1st_Sludge Volume Index  \
# 2017-01-03           105.593607                 0.000000
# 2017-01-04           105.593607                 0.000000
# 2017-01-05           113.661202                 8.067595
# 2017-01-06           104.875283                -8.785919
# 2017-01-07           115.632313                10.757029
# 2017-01-08           126.389342                10.757029
# 2017-01-09           137.146371                10.757029
# 2017-01-10           114.124294               -23.022078
# 2017-01-11           104.994903                -9.129391
# 2017-01-12            91.185410               -13.809493
#
#             2nd_Sludge Volume Index
# 2017-01-03             0.000000e+00
# 2017-01-04             0.000000e+00
# 2017-01-05             8.067595e+00
# 2017-01-06            -1.685351e+01
# 2017-01-07             1.954295e+01
# 2017-01-08            -9.947598e-14
# 2017-01-09             8.526513e-14
# 2017-01-10            -3.377911e+01
# 2017-01-11             1.389269e+01
# 2017-01-12            -4.680102e+00

# %%
# Checked feature names

for column_title in df.columns:
    print(column_title)
# Out:
# Sludge Volume Index
# SE NH3
# MLSS
# RAS TSS
# Alum Feed 1
# Alum Feed 2
# Activated Sludge Flow
# Primary Sludge A Flow
# Primary Sludge B Flow
# Ana F:M
# RAS Flow
# Avg ND Effluent Hourly Ammonia
# Avg ND WAS Flow
# Avg ND Aeration DO Cell 5 AVG
# Avg ND Aeration DO Cell 7 AVG
# Avg ND Aer. Avg Cell 7 Nitrate
# Avg ND Average Basin Airflow
# day
# month
# year
# Total Alum Feed
# Total Primary Sludge Flow
# Average ND Aeration DO in Cells
# MVLSS
# MCRT
# Sludge Age
# 1st_Sludge Volume Index
# 1st_SE NH3
# 1st_MLSS
# 1st_RAS TSS
# 1st_Alum Feed 1
# 1st_Alum Feed 2
# 1st_Activated Sludge Flow
# 1st_Primary Sludge A Flow
# 1st_Primary Sludge B Flow
# 1st_Ana F:M
# 1st_RAS Flow
# 1st_Avg ND Effluent Hourly Ammonia
# 1st_Avg ND WAS Flow
# 1st_Avg ND Aeration DO Cell 5 AVG
# 1st_Avg ND Aeration DO Cell 7 AVG
# 1st_Avg ND Aer. Avg Cell 7 Nitrate
# 1st_Avg ND Average Basin Airflow
# 1st_Total Alum Feed
# 1st_Total Primary Sludge Flow
# 1st_Average ND Aeration DO in Cells
# 1st_MVLSS
# 1st_MCRT
# 1st_Sludge Age
# 2nd_Sludge Volume Index
# 2nd_SE NH3
# 2nd_MLSS
# 2nd_RAS TSS
# 2nd_Alum Feed 1
# 2nd_Alum Feed 2
# 2nd_Activated Sludge Flow
# 2nd_Primary Sludge A Flow
# 2nd_Primary Sludge B Flow
# 2nd_Ana F:M
# 2nd_RAS Flow
# 2nd_Avg ND Effluent Hourly Ammonia
# 2nd_Avg ND WAS Flow
# 2nd_Avg ND Aeration DO Cell 5 AVG
# 2nd_Avg ND Aeration DO Cell 7 AVG
# 2nd_Avg ND Aer. Avg Cell 7 Nitrate
# 2nd_Avg ND Average Basin Airflow
# 2nd_Total Alum Feed
# 2nd_Total Primary Sludge Flow
# 2nd_Average ND Aeration DO in Cells
# 2nd_MVLSS
# 2nd_MCRT
# 2nd_Sludge Age

# %% [markdown]
# #### Lag features

# %% [markdown]
# I created lagged versions of metrics of one through seven days since SVI tends to change over the course of weeks.

# %%
# Lagged features by 1 through 7 days.

explanatory_vars = df.columns[~df.columns.isin(['day', 'month', 'year'])]
lagged_columns = []

lagged_df = pd.DataFrame()

for lag in range(1, 8):
    lagged_columns.extend([f'{var}_lag_{lag}' for var in explanatory_vars])
    lagged_data = {f"{var}_lag_{lag}": df[var].shift(lag) for var in explanatory_vars}
    lagged_df = pd.concat([lagged_df, pd.DataFrame(lagged_data)], axis=1)

df = pd.concat([df, lagged_df], axis=1)

# %%
# Dropped rows containng NaN as a result of lagged features.

df.dropna(inplace=True)

# %%
# Looked at just SVI to check lagging.

selected_columns = ['Sludge Volume Index', 'Sludge Volume Index_lag_1', 'Sludge Volume Index_lag_2', 'Sludge Volume Index_lag_3', 'Sludge Volume Index_lag_4']
new_df = df.loc[:, selected_columns]
new_df.head(10)
# Out:
#             Sludge Volume Index  Sludge Volume Index_lag_1  \
# 2017-01-10           114.124294                 137.146371
# 2017-01-11           104.994903                 114.124294
# 2017-01-12            91.185410                 104.994903
# 2017-01-13            93.179635                  91.185410
# 2017-01-14            94.544590                  93.179635
# 2017-01-15            95.909545                  94.544590
# 2017-01-16            97.274501                  95.909545
# 2017-01-17            98.639456                  97.274501
# 2017-01-18           118.541033                  98.639456
# 2017-01-19           106.382979                 118.541033
#
#             Sludge Volume Index_lag_2  Sludge Volume Index_lag_3  \
# 2017-01-10                 126.389342                 115.632313
# 2017-01-11                 137.146371                 126.389342
# 2017-01-12                 114.124294                 137.146371
# 2017-01-13                 104.994903                 114.124294
# 2017-01-14                  91.185410                 104.994903
# 2017-01-15                  93.179635                  91.185410
# 2017-01-16                  94.544590                  93.179635
# 2017-01-17                  95.909545                  94.544590
# 2017-01-18                  97.274501                  95.909545
# 2017-01-19                  98.639456                  97.274501
#
#             Sludge Volume Index_lag_4
# 2017-01-10                 104.875283
# 2017-01-11                 115.632313
# 2017-01-12                 126.389342
# 2017-01-13                 137.146371
# 2017-01-14                 114.124294
# 2017-01-15                 104.994903
# 2017-01-16                  91.185410
# 2017-01-17                  93.179635
# 2017-01-18                  94.544590
# 2017-01-19                  95.909545

# %%
# Printed list of column titles to check results of lagging.

for column_title in df.columns:
    print(column_title)
# Out:
# Sludge Volume Index
# SE NH3
# MLSS
# RAS TSS
# Alum Feed 1
# Alum Feed 2
# Activated Sludge Flow
# Primary Sludge A Flow
# Primary Sludge B Flow
# Ana F:M
# RAS Flow
# Avg ND Effluent Hourly Ammonia
# Avg ND WAS Flow
# Avg ND Aeration DO Cell 5 AVG
# Avg ND Aeration DO Cell 7 AVG
# Avg ND Aer. Avg Cell 7 Nitrate
# Avg ND Average Basin Airflow
# day
# month
# year
# Total Alum Feed
# Total Primary Sludge Flow
# Average ND Aeration DO in Cells
# MVLSS
# MCRT
# Sludge Age
# 1st_Sludge Volume Index
# 1st_SE NH3
# 1st_MLSS
# 1st_RAS TSS
# 1st_Alum Feed 1
# 1st_Alum Feed 2
# 1st_Activated Sludge Flow
# 1st_Primary Sludge A Flow
# 1st_Primary Sludge B Flow
# 1st_Ana F:M
# 1st_RAS Flow
# 1st_Avg ND Effluent Hourly Ammonia
# 1st_Avg ND WAS Flow
# 1st_Avg ND Aeration DO Cell 5 AVG
# 1st_Avg ND Aeration DO Cell 7 AVG
# 1st_Avg ND Aer. Avg Cell 7 Nitrate
# 1st_Avg ND Average Basin Airflow
# 1st_Total Alum Feed
# 1st_Total Primary Sludge Flow
# 1st_Average ND Aeration DO in Cells
# 1st_MVLSS
# 1st_MCRT
# 1st_Sludge Age
# 2nd_Sludge Volume Index
# 2nd_SE NH3
# 2nd_MLSS
# 2nd_RAS TSS
# 2nd_Alum Feed 1
# 2nd_Alum Feed 2
# 2nd_Activated Sludge Flow
# 2nd_Primary Sludge A Flow
# 2nd_Primary Sludge B Flow
# 2nd_Ana F:M
# 2nd_RAS Flow
# 2nd_Avg ND Effluent Hourly Ammonia
# 2nd_Avg ND WAS Flow
# 2nd_Avg ND Aeration DO Cell 5 AVG
# 2nd_Avg ND Aeration DO Cell 7 AVG
# 2nd_Avg ND Aer. Avg Cell 7 Nitrate
# 2nd_Avg ND Average Basin Airflow
# 2nd_Total Alum Feed
# 2nd_Total Primary Sludge Flow
# 2nd_Average ND Aeration DO in Cells
# 2nd_MVLSS
# 2nd_MCRT
# 2nd_Sludge Age
# Sludge Volume Index_lag_1
# SE NH3_lag_1
# MLSS_lag_1
# RAS TSS_lag_1
# Alum Feed 1_lag_1
# Alum Feed 2_lag_1
# Activated Sludge Flow_lag_1
# Primary Sludge A Flow_lag_1
# Primary Sludge B Flow_lag_1
# Ana F:M_lag_1
# RAS Flow_lag_1
# Avg ND Effluent Hourly Ammonia_lag_1
# Avg ND WAS Flow_lag_1
# Avg ND Aeration DO Cell 5 AVG_lag_1
# Avg ND Aeration DO Cell 7 AVG_lag_1
# Avg ND Aer. Avg Cell 7 Nitrate_lag_1
# Avg ND Average Basin Airflow_lag_1
# Total Alum Feed_lag_1
# Total Primary Sludge Flow_lag_1
# Average ND Aeration DO in Cells_lag_1
# MVLSS_lag_1
# MCRT_lag_1
# Sludge Age_lag_1
# 1st_Sludge Volume Index_lag_1
# 1st_SE NH3_lag_1
# 1st_MLSS_lag_1
# 1st_RAS TSS_lag_1
# 1st_Alum Feed 1_lag_1
# 1st_Alum Feed 2_lag_1
# 1st_Activated Sludge Flow_lag_1
# 1st_Primary Sludge A Flow_lag_1
# 1st_Primary Sludge B Flow_lag_1
# 1st_Ana F:M_lag_1
# 1st_RAS Flow_lag_1
# 1st_Avg ND Effluent Hourly Ammonia_lag_1
# 1st_Avg ND WAS Flow_lag_1
# 1st_Avg ND Aeration DO Cell 5 AVG_lag_1
# 1st_Avg ND Aeration DO Cell 7 AVG_lag_1
# 1st_Avg ND Aer. Avg Cell 7 Nitrate_lag_1
# 1st_Avg ND Average Basin Airflow_lag_1
# 1st_Total Alum Feed_lag_1
# 1st_Total Primary Sludge Flow_lag_1
# 1st_Average ND Aeration DO in Cells_lag_1
# 1st_MVLSS_lag_1
# 1st_MCRT_lag_1
# 1st_Sludge Age_lag_1
# 2nd_Sludge Volume Index_lag_1
# 2nd_SE NH3_lag_1
# 2nd_MLSS_lag_1
# 2nd_RAS TSS_lag_1
# 2nd_Alum Feed 1_lag_1
# 2nd_Alum Feed 2_lag_1
# 2nd_Activated Sludge Flow_lag_1
# 2nd_Primary Sludge A Flow_lag_1
# 2nd_Primary Sludge B Flow_lag_1
# 2nd_Ana F:M_lag_1
# 2nd_RAS Flow_lag_1
# 2nd_Avg ND Effluent Hourly Ammonia_lag_1
# 2nd_Avg ND WAS Flow_lag_1
# 2nd_Avg ND Aeration DO Cell 5 AVG_lag_1
# 2nd_Avg ND Aeration DO Cell 7 AVG_lag_1
# 2nd_Avg ND Aer. Avg Cell 7 Nitrate_lag_1
# 2nd_Avg ND Average Basin Airflow_lag_1
# 2nd_Total Alum Feed_lag_1
# 2nd_Total Primary Sludge Flow_lag_1
# 2nd_Average ND Aeration DO in Cells_lag_1
# 2nd_MVLSS_lag_1
# 2nd_MCRT_lag_1
# 2nd_Sludge Age_lag_1
# Sludge Volume Index_lag_2
# SE NH3_lag_2
# MLSS_lag_2
# RAS TSS_lag_2
# Alum Feed 1_lag_2
# Alum Feed 2_lag_2
# Activated Sludge Flow_lag_2
# Primary Sludge A Flow_lag_2
# Primary Sludge B Flow_lag_2
# Ana F:M_lag_2
# RAS Flow_lag_2
# Avg ND Effluent Hourly Ammonia_lag_2
# Avg ND WAS Flow_lag_2
# Avg ND Aeration DO Cell 5 AVG_lag_2
# Avg ND Aeration DO Cell 7 AVG_lag_2
# Avg ND Aer. Avg Cell 7 Nitrate_lag_2
# Avg ND Average Basin Airflow_lag_2
# Total Alum Feed_lag_2
# Total Primary Sludge Flow_lag_2
# Average ND Aeration DO in Cells_lag_2
# MVLSS_lag_2
# MCRT_lag_2
# Sludge Age_lag_2
# 1st_Sludge Volume Index_lag_2
# 1st_SE NH3_lag_2
# 1st_MLSS_lag_2
# 1st_RAS TSS_lag_2
# 1st_Alum Feed 1_lag_2
# 1st_Alum Feed 2_lag_2
# 1st_Activated Sludge Flow_lag_2
# 1st_Primary Sludge A Flow_lag_2
# 1st_Primary Sludge B Flow_lag_2
# 1st_Ana F:M_lag_2
# 1st_RAS Flow_lag_2
# 1st_Avg ND Effluent Hourly Ammonia_lag_2
# 1st_Avg ND WAS Flow_lag_2
# 1st_Avg ND Aeration DO Cell 5 AVG_lag_2
# 1st_Avg ND Aeration DO Cell 7 AVG_lag_2
# 1st_Avg ND Aer. Avg Cell 7 Nitrate_lag_2
# 1st_Avg ND Average Basin Airflow_lag_2
# 1st_Total Alum Feed_lag_2
# 1st_Total Primary Sludge Flow_lag_2
# 1st_Average ND Aeration DO in Cells_lag_2
# 1st_MVLSS_lag_2
# 1st_MCRT_lag_2
# 1st_Sludge Age_lag_2
# 2nd_Sludge Volume Index_lag_2
# 2nd_SE NH3_lag_2
# 2nd_MLSS_lag_2
# 2nd_RAS TSS_lag_2
# 2nd_Alum Feed 1_lag_2
# 2nd_Alum Feed 2_lag_2
# 2nd_Activated Sludge Flow_lag_2
# 2nd_Primary Sludge A Flow_lag_2
# 2nd_Primary Sludge B Flow_lag_2
# 2nd_Ana F:M_lag_2
# 2nd_RAS Flow_lag_2
# 2nd_Avg ND Effluent Hourly Ammonia_lag_2
# 2nd_Avg ND WAS Flow_lag_2
# 2nd_Avg ND Aeration DO Cell 5 AVG_lag_2
# 2nd_Avg ND Aeration DO Cell 7 AVG_lag_2
# 2nd_Avg ND Aer. Avg Cell 7 Nitrate_lag_2
# 2nd_Avg ND Average Basin Airflow_lag_2
# 2nd_Total Alum Feed_lag_2
# 2nd_Total Primary Sludge Flow_lag_2
# 2nd_Average ND Aeration DO in Cells_lag_2
# 2nd_MVLSS_lag_2
# 2nd_MCRT_lag_2
# 2nd_Sludge Age_lag_2
# Sludge Volume Index_lag_3
# SE NH3_lag_3
# MLSS_lag_3
# RAS TSS_lag_3
# Alum Feed 1_lag_3
# Alum Feed 2_lag_3
# Activated Sludge Flow_lag_3
# Primary Sludge A Flow_lag_3
# Primary Sludge B Flow_lag_3
# Ana F:M_lag_3
# RAS Flow_lag_3
# Avg ND Effluent Hourly Ammonia_lag_3
# Avg ND WAS Flow_lag_3
# Avg ND Aeration DO Cell 5 AVG_lag_3
# Avg ND Aeration DO Cell 7 AVG_lag_3
# Avg ND Aer. Avg Cell 7 Nitrate_lag_3
# Avg ND Average Basin Airflow_lag_3
# Total Alum Feed_lag_3
# Total Primary Sludge Flow_lag_3
# Average ND Aeration DO in Cells_lag_3
# MVLSS_lag_3
# MCRT_lag_3
# Sludge Age_lag_3
# 1st_Sludge Volume Index_lag_3
# 1st_SE NH3_lag_3
# 1st_MLSS_lag_3
# 1st_RAS TSS_lag_3
# 1st_Alum Feed 1_lag_3
# 1st_Alum Feed 2_lag_3
# 1st_Activated Sludge Flow_lag_3
# 1st_Primary Sludge A Flow_lag_3
# 1st_Primary Sludge B Flow_lag_3
# 1st_Ana F:M_lag_3
# 1st_RAS Flow_lag_3
# 1st_Avg ND Effluent Hourly Ammonia_lag_3
# 1st_Avg ND WAS Flow_lag_3
# 1st_Avg ND Aeration DO Cell 5 AVG_lag_3
# 1st_Avg ND Aeration DO Cell 7 AVG_lag_3
# 1st_Avg ND Aer. Avg Cell 7 Nitrate_lag_3
# 1st_Avg ND Average Basin Airflow_lag_3
# 1st_Total Alum Feed_lag_3
# 1st_Total Primary Sludge Flow_lag_3
# 1st_Average ND Aeration DO in Cells_lag_3
# 1st_MVLSS_lag_3
# 1st_MCRT_lag_3
# 1st_Sludge Age_lag_3
# 2nd_Sludge Volume Index_lag_3
# 2nd_SE NH3_lag_3
# 2nd_MLSS_lag_3
# 2nd_RAS TSS_lag_3
# 2nd_Alum Feed 1_lag_3
# 2nd_Alum Feed 2_lag_3
# 2nd_Activated Sludge Flow_lag_3
# 2nd_Primary Sludge A Flow_lag_3
# 2nd_Primary Sludge B Flow_lag_3
# 2nd_Ana F:M_lag_3
# 2nd_RAS Flow_lag_3
# 2nd_Avg ND Effluent Hourly Ammonia_lag_3
# 2nd_Avg ND WAS Flow_lag_3
# 2nd_Avg ND Aeration DO Cell 5 AVG_lag_3
# 2nd_Avg ND Aeration DO Cell 7 AVG_lag_3
# 2nd_Avg ND Aer. Avg Cell 7 Nitrate_lag_3
# 2nd_Avg ND Average Basin Airflow_lag_3
# 2nd_Total Alum Feed_lag_3
# 2nd_Total Primary Sludge Flow_lag_3
# 2nd_Average ND Aeration DO in Cells_lag_3
# 2nd_MVLSS_lag_3
# 2nd_MCRT_lag_3
# 2nd_Sludge Age_lag_3
# Sludge Volume Index_lag_4
# SE NH3_lag_4
# MLSS_lag_4
# RAS TSS_lag_4
# Alum Feed 1_lag_4
# Alum Feed 2_lag_4
# Activated Sludge Flow_lag_4
# Primary Sludge A Flow_lag_4
# Primary Sludge B Flow_lag_4
# Ana F:M_lag_4
# RAS Flow_lag_4
# Avg ND Effluent Hourly Ammonia_lag_4
# Avg ND WAS Flow_lag_4
# Avg ND Aeration DO Cell 5 AVG_lag_4
# Avg ND Aeration DO Cell 7 AVG_lag_4
# Avg ND Aer. Avg Cell 7 Nitrate_lag_4
# Avg ND Average Basin Airflow_lag_4
# Total Alum Feed_lag_4
# Total Primary Sludge Flow_lag_4
# Average ND Aeration DO in Cells_lag_4
# MVLSS_lag_4
# MCRT_lag_4
# Sludge Age_lag_4
# 1st_Sludge Volume Index_lag_4
# 1st_SE NH3_lag_4
# 1st_MLSS_lag_4
# 1st_RAS TSS_lag_4
# 1st_Alum Feed 1_lag_4
# 1st_Alum Feed 2_lag_4
# 1st_Activated Sludge Flow_lag_4
# 1st_Primary Sludge A Flow_lag_4
# 1st_Primary Sludge B Flow_lag_4
# 1st_Ana F:M_lag_4
# 1st_RAS Flow_lag_4
# 1st_Avg ND Effluent Hourly Ammonia_lag_4
# 1st_Avg ND WAS Flow_lag_4
# 1st_Avg ND Aeration DO Cell 5 AVG_lag_4
# 1st_Avg ND Aeration DO Cell 7 AVG_lag_4
# 1st_Avg ND Aer. Avg Cell 7 Nitrate_lag_4
# 1st_Avg ND Average Basin Airflow_lag_4
# 1st_Total Alum Feed_lag_4
# 1st_Total Primary Sludge Flow_lag_4
# 1st_Average ND Aeration DO in Cells_lag_4
# 1st_MVLSS_lag_4
# 1st_MCRT_lag_4
# 1st_Sludge Age_lag_4
# 2nd_Sludge Volume Index_lag_4
# 2nd_SE NH3_lag_4
# 2nd_MLSS_lag_4
# 2nd_RAS TSS_lag_4
# 2nd_Alum Feed 1_lag_4
# 2nd_Alum Feed 2_lag_4
# 2nd_Activated Sludge Flow_lag_4
# 2nd_Primary Sludge A Flow_lag_4
# 2nd_Primary Sludge B Flow_lag_4
# 2nd_Ana F:M_lag_4
# 2nd_RAS Flow_lag_4
# 2nd_Avg ND Effluent Hourly Ammonia_lag_4
# 2nd_Avg ND WAS Flow_lag_4
# 2nd_Avg ND Aeration DO Cell 5 AVG_lag_4
# 2nd_Avg ND Aeration DO Cell 7 AVG_lag_4
# 2nd_Avg ND Aer. Avg Cell 7 Nitrate_lag_4
# 2nd_Avg ND Average Basin Airflow_lag_4
# 2nd_Total Alum Feed_lag_4
# 2nd_Total Primary Sludge Flow_lag_4
# 2nd_Average ND Aeration DO in Cells_lag_4
# 2nd_MVLSS_lag_4
# 2nd_MCRT_lag_4
# 2nd_Sludge Age_lag_4
# Sludge Volume Index_lag_5
# SE NH3_lag_5
# MLSS_lag_5
# RAS TSS_lag_5
# Alum Feed 1_lag_5
# Alum Feed 2_lag_5
# Activated Sludge Flow_lag_5
# Primary Sludge A Flow_lag_5
# Primary Sludge B Flow_lag_5
# Ana F:M_lag_5
# RAS Flow_lag_5
# Avg ND Effluent Hourly Ammonia_lag_5
# Avg ND WAS Flow_lag_5
# Avg ND Aeration DO Cell 5 AVG_lag_5
# Avg ND Aeration DO Cell 7 AVG_lag_5
# Avg ND Aer. Avg Cell 7 Nitrate_lag_5
# Avg ND Average Basin Airflow_lag_5
# Total Alum Feed_lag_5
# Total Primary Sludge Flow_lag_5
# Average ND Aeration DO in Cells_lag_5
# MVLSS_lag_5
# MCRT_lag_5
# Sludge Age_lag_5
# 1st_Sludge Volume Index_lag_5
# 1st_SE NH3_lag_5
# 1st_MLSS_lag_5
# 1st_RAS TSS_lag_5
# 1st_Alum Feed 1_lag_5
# 1st_Alum Feed 2_lag_5
# 1st_Activated Sludge Flow_lag_5
# 1st_Primary Sludge A Flow_lag_5
# 1st_Primary Sludge B Flow_lag_5
# 1st_Ana F:M_lag_5
# 1st_RAS Flow_lag_5
# 1st_Avg ND Effluent Hourly Ammonia_lag_5
# 1st_Avg ND WAS Flow_lag_5
# 1st_Avg ND Aeration DO Cell 5 AVG_lag_5
# 1st_Avg ND Aeration DO Cell 7 AVG_lag_5
# 1st_Avg ND Aer. Avg Cell 7 Nitrate_lag_5
# 1st_Avg ND Average Basin Airflow_lag_5
# 1st_Total Alum Feed_lag_5
# 1st_Total Primary Sludge Flow_lag_5
# 1st_Average ND Aeration DO in Cells_lag_5
# 1st_MVLSS_lag_5
# 1st_MCRT_lag_5
# 1st_Sludge Age_lag_5
# 2nd_Sludge Volume Index_lag_5
# 2nd_SE NH3_lag_5
# 2nd_MLSS_lag_5
# 2nd_RAS TSS_lag_5
# 2nd_Alum Feed 1_lag_5
# 2nd_Alum Feed 2_lag_5
# 2nd_Activated Sludge Flow_lag_5
# 2nd_Primary Sludge A Flow_lag_5
# 2nd_Primary Sludge B Flow_lag_5
# 2nd_Ana F:M_lag_5
# 2nd_RAS Flow_lag_5
# 2nd_Avg ND Effluent Hourly Ammonia_lag_5
# 2nd_Avg ND WAS Flow_lag_5
# 2nd_Avg ND Aeration DO Cell 5 AVG_lag_5
# 2nd_Avg ND Aeration DO Cell 7 AVG_lag_5
# 2nd_Avg ND Aer. Avg Cell 7 Nitrate_lag_5
# 2nd_Avg ND Average Basin Airflow_lag_5
# 2nd_Total Alum Feed_lag_5
# 2nd_Total Primary Sludge Flow_lag_5
# 2nd_Average ND Aeration DO in Cells_lag_5
# 2nd_MVLSS_lag_5
# 2nd_MCRT_lag_5
# 2nd_Sludge Age_lag_5
# Sludge Volume Index_lag_6
# SE NH3_lag_6
# MLSS_lag_6
# RAS TSS_lag_6
# Alum Feed 1_lag_6
# Alum Feed 2_lag_6
# Activated Sludge Flow_lag_6
# Primary Sludge A Flow_lag_6
# Primary Sludge B Flow_lag_6
# Ana F:M_lag_6
# RAS Flow_lag_6
# Avg ND Effluent Hourly Ammonia_lag_6
# Avg ND WAS Flow_lag_6
# Avg ND Aeration DO Cell 5 AVG_lag_6
# Avg ND Aeration DO Cell 7 AVG_lag_6
# Avg ND Aer. Avg Cell 7 Nitrate_lag_6
# Avg ND Average Basin Airflow_lag_6
# Total Alum Feed_lag_6
# Total Primary Sludge Flow_lag_6
# Average ND Aeration DO in Cells_lag_6
# MVLSS_lag_6
# MCRT_lag_6
# Sludge Age_lag_6
# 1st_Sludge Volume Index_lag_6
# 1st_SE NH3_lag_6
# 1st_MLSS_lag_6
# 1st_RAS TSS_lag_6
# 1st_Alum Feed 1_lag_6
# 1st_Alum Feed 2_lag_6
# 1st_Activated Sludge Flow_lag_6
# 1st_Primary Sludge A Flow_lag_6
# 1st_Primary Sludge B Flow_lag_6
# 1st_Ana F:M_lag_6
# 1st_RAS Flow_lag_6
# 1st_Avg ND Effluent Hourly Ammonia_lag_6
# 1st_Avg ND WAS Flow_lag_6
# 1st_Avg ND Aeration DO Cell 5 AVG_lag_6
# 1st_Avg ND Aeration DO Cell 7 AVG_lag_6
# 1st_Avg ND Aer. Avg Cell 7 Nitrate_lag_6
# 1st_Avg ND Average Basin Airflow_lag_6
# 1st_Total Alum Feed_lag_6
# 1st_Total Primary Sludge Flow_lag_6
# 1st_Average ND Aeration DO in Cells_lag_6
# 1st_MVLSS_lag_6
# 1st_MCRT_lag_6
# 1st_Sludge Age_lag_6
# 2nd_Sludge Volume Index_lag_6
# 2nd_SE NH3_lag_6
# 2nd_MLSS_lag_6
# 2nd_RAS TSS_lag_6
# 2nd_Alum Feed 1_lag_6
# 2nd_Alum Feed 2_lag_6
# 2nd_Activated Sludge Flow_lag_6
# 2nd_Primary Sludge A Flow_lag_6
# 2nd_Primary Sludge B Flow_lag_6
# 2nd_Ana F:M_lag_6
# 2nd_RAS Flow_lag_6
# 2nd_Avg ND Effluent Hourly Ammonia_lag_6
# 2nd_Avg ND WAS Flow_lag_6
# 2nd_Avg ND Aeration DO Cell 5 AVG_lag_6
# 2nd_Avg ND Aeration DO Cell 7 AVG_lag_6
# 2nd_Avg ND Aer. Avg Cell 7 Nitrate_lag_6
# 2nd_Avg ND Average Basin Airflow_lag_6
# 2nd_Total Alum Feed_lag_6
# 2nd_Total Primary Sludge Flow_lag_6
# 2nd_Average ND Aeration DO in Cells_lag_6
# 2nd_MVLSS_lag_6
# 2nd_MCRT_lag_6
# 2nd_Sludge Age_lag_6
# Sludge Volume Index_lag_7
# SE NH3_lag_7
# MLSS_lag_7
# RAS TSS_lag_7
# Alum Feed 1_lag_7
# Alum Feed 2_lag_7
# Activated Sludge Flow_lag_7
# Primary Sludge A Flow_lag_7
# Primary Sludge B Flow_lag_7
# Ana F:M_lag_7
# RAS Flow_lag_7
# Avg ND Effluent Hourly Ammonia_lag_7
# Avg ND WAS Flow_lag_7
# Avg ND Aeration DO Cell 5 AVG_lag_7
# Avg ND Aeration DO Cell 7 AVG_lag_7
# Avg ND Aer. Avg Cell 7 Nitrate_lag_7
# Avg ND Average Basin Airflow_lag_7
# Total Alum Feed_lag_7
# Total Primary Sludge Flow_lag_7
# Average ND Aeration DO in Cells_lag_7
# MVLSS_lag_7
# MCRT_lag_7
# Sludge Age_lag_7
# 1st_Sludge Volume Index_lag_7
# 1st_SE NH3_lag_7
# 1st_MLSS_lag_7
# 1st_RAS TSS_lag_7
# 1st_Alum Feed 1_lag_7
# 1st_Alum Feed 2_lag_7
# 1st_Activated Sludge Flow_lag_7
# 1st_Primary Sludge A Flow_lag_7
# 1st_Primary Sludge B Flow_lag_7
# 1st_Ana F:M_lag_7
# 1st_RAS Flow_lag_7
# 1st_Avg ND Effluent Hourly Ammonia_lag_7
# 1st_Avg ND WAS Flow_lag_7
# 1st_Avg ND Aeration DO Cell 5 AVG_lag_7
# 1st_Avg ND Aeration DO Cell 7 AVG_lag_7
# 1st_Avg ND Aer. Avg Cell 7 Nitrate_lag_7
# 1st_Avg ND Average Basin Airflow_lag_7
# 1st_Total Alum Feed_lag_7
# 1st_Total Primary Sludge Flow_lag_7
# 1st_Average ND Aeration DO in Cells_lag_7
# 1st_MVLSS_lag_7
# 1st_MCRT_lag_7
# 1st_Sludge Age_lag_7
# 2nd_Sludge Volume Index_lag_7
# 2nd_SE NH3_lag_7
# 2nd_MLSS_lag_7
# 2nd_RAS TSS_lag_7
# 2nd_Alum Feed 1_lag_7
# 2nd_Alum Feed 2_lag_7
# 2nd_Activated Sludge Flow_lag_7
# 2nd_Primary Sludge A Flow_lag_7
# 2nd_Primary Sludge B Flow_lag_7
# 2nd_Ana F:M_lag_7
# 2nd_RAS Flow_lag_7
# 2nd_Avg ND Effluent Hourly Ammonia_lag_7
# 2nd_Avg ND WAS Flow_lag_7
# 2nd_Avg ND Aeration DO Cell 5 AVG_lag_7
# 2nd_Avg ND Aeration DO Cell 7 AVG_lag_7
# 2nd_Avg ND Aer. Avg Cell 7 Nitrate_lag_7
# 2nd_Avg ND Average Basin Airflow_lag_7
# 2nd_Total Alum Feed_lag_7
# 2nd_Total Primary Sludge Flow_lag_7
# 2nd_Average ND Aeration DO in Cells_lag_7
# 2nd_MVLSS_lag_7
# 2nd_MCRT_lag_7
# 2nd_Sludge Age_lag_7

# %%
# Saved to Excel
df.to_excel('/Users/NJahns/Desktop/Bootcamp/Capstone_Two/Edited_Data/Pre_Process_Train.xlsx', index=True)

# %% [markdown]
# I did not include splitting the data into testing and training datasets in this workbook becasue it makes more sense to include those steps with model development as they are mixed into the model development steps.
